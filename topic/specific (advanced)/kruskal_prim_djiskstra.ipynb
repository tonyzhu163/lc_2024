# %%
# Minimum spanning trees
# kruskal

# %%
# Minimum spanning trees
# prim

# %%
# minimum depth of binary tree

class Solution:
    def minDepth(self, root: Optional[TreeNode]) -> int:
        if not root:
            return 0
        
        q = deque()
        q.append(root)
        
        mx = 1
        
        while q:
            for _ in range(len(q)):
                cur = q.popleft()

                if not cur.left and not cur.right:
                    return mx

                if cur.left:
                    q.append(cur.left)

                if cur.right:
                    q.append(cur.right)
                
            mx += 1
        
        return mx

# %%
# level traversal

class Solution:
    def levelOrder(self, root: Optional[TreeNode]) -> List[List[int]]:
        res = []

        if not root:
            return res

        q = deque()
        q.append(root)

        while q:
            # we need to stop at each layer
            sz = len(q)
            level = []
            for _ in range(sz):
                cur = q.popleft()
                level.append(cur.val)
                if cur.left:
                    q.append(cur.left)
                if cur.right:
                    q.append(cur.right)
            
            res.append(level)
        
        return res

# %%
# Djisktra 

# a graph with positive weights
# BFS is doing weight = 1

# basically a BFS with DP table (use state variable)

# we dont need visited since PQ updates only with smaller distance
# Bellman Ford is more advanced (negative weights

# Time Complexity
# BFS, DFS, TS O(E+V)
# O((E + V) log V) due to PQ


from queue import PriorityQueue

class State:
    def __init__(self, id, dist):
        self.id = id
        self.dist = dist


def djikstra(graph, start):
    V = len(graph)
    
    # record distance
    table = [float('inf')] * V

    table[start] = 0

    pq = PriorityQueue(lambda a,b: a.dist - b.dist)

    pq.put(State(start, 0))

    while not pq.empty():
        curid, curdist = pq.get()
        
        # there is a better path
        if curdist > table[curid]:
            continue

        for nextid in graph[curid]:
            newdist= table[curid] + weight(curid, nextid)
            if newdist <= table[curid]:
                table[next] = newdist
                pq.put(State(nextid, newdist))
    
    return table
